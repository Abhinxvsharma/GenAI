# %%
a=10
b=30
print(a+b)
# Out:
# 40

# %%
funcs()
# Out:
# Hello

# %%
print(a*b)
# Out:
# 300

# %%
def funcs():
    print("Hello")

# %% [markdown]
# #### pandas

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
# data - 2 types 
# 1D Data - Series 
# 2D Data - DataFrames

# %%
# series - [], {}

# %%
s1= pd.Series([45,85,'Hello',True,12,11.23,19])
print(s1)
# Out:
# 0       45
# 1       85
# 2    Hello
# 3     True
# 4       12
# 5    11.23
# 6       19
# dtype: object

# %%
s2= pd.Series([12,45,66,32,11])
s2
# Out:
# 0    12
# 1    45
# 2    66
# 3    32
# 4    11
# dtype: int64

# %%
s3= pd.Series([55,45,12,90,88,76],index=[5,6,7,8,9,10])
s3
# Out:
# 5     55
# 6     45
# 7     12
# 8     90
# 9     88
# 10    76
# dtype: int64

# %%
s4= pd.Series([55,45,12,90,88,76],index=['a','b','c','d','e','f'])
s4
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# f    76
# dtype: int64

# %%
s5= pd.Series([ i**2 for i in range(5,15)], index=[i for i in range(5,15)])
s5
# Out:
# 5      25
# 6      36
# 7      49
# 8      64
# 9      81
# 10    100
# 11    121
# 12    144
# 13    169
# 14    196
# dtype: int64

# %%
# access - [], .

# %%
s2
# Out:
# 0    12
# 1    45
# 2    66
# 3    32
# 4    11
# dtype: int64

# %%
# s2[:1]
s2[1]
# Out:
# 45

# %%
s2[3]
# Out:
# 32

# %%
s3[7]
# Out:
# 12

# %%
s4
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# f    76
# dtype: int64

# %%
s4[0]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19964\957271931.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s4[0]
# 55

# %%
s4['a']
# Out:
# 55

# %%
s4['b']
# Out:
# 45

# %%
s4.e
# Out:
# 88

# %%
# s3.5
# Out:
#   Cell In[39], line 1
#     s3.5
#       ^
# SyntaxError: invalid syntax

# %%
# loc, iloc -- location(labels), iloc index location(index by default)

# %%
s4
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# f    76
# dtype: int64

# %%
s3
# Out:
# 5     55
# 6     45
# 7     12
# 8     90
# 9     88
# 10    76
# dtype: int64

# %%
s2
# Out:
# 0    12
# 1    45
# 2    66
# 3    32
# 4    11
# dtype: int64

# %%
s2.loc[:2]
# Out:
# 0    12
# 1    45
# 2    66
# dtype: int64

# %%
s2.iloc[:2]
# Out:
# 0    12
# 1    45
# dtype: int64

# %%
s4
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# f    76
# dtype: int64

# %%
s4.loc['a':'e']
# Out:
# a    55
# b    45
# c    12
# d    90
# e    88
# dtype: int64

# %%
s4.iloc[3]
# Out:
# 90

# %%
# s4.iloc['a'] - error
