# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.drop("Cabin",axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.Name.value_counts()
# Out:
# Name
# Braund, Mr. Owen Harris                                1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
# Allen, Mr. William Henry                               1
#                                                       ..
# Montvila, Rev. Juozas                                  1
# Graham, Miss. Margaret Edith                           1
# Johnston, Miss. Catherine Helen "Carrie"               1
# Behr, Mr. Karl Howell                                  1
# Dooley, Mr. Patrick                                    1
# Name: count, Length: 891, dtype: int64

# %%
new = df.Name.str.split(",").str[1].str.split(".").str[0].str.strip()

# %%
new
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Name, Length: 891, dtype: object

# %%
df.insert(4,"title",new)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name title     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    Mr    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs  female  38.0
# 2                             Heikkinen, Miss. Laina  Miss  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Mrs  female  35.0
# 4                           Allen, Mr. William Henry    Mr    male  35.0
#
#    SibSp  Parch            Ticket     Fare Embarked
# 0      1      0         A/5 21171   7.2500        S
# 1      1      0          PC 17599  71.2833        C
# 2      0      0  STON/O2. 3101282   7.9250        S
# 3      1      0            113803  53.1000        S
# 4      0      0            373450   8.0500        S

# %%
mr_df = df[df.loc[:,"title"] == "Mr"]

# %%
mr_df
# Out:
#      PassengerId  Survived  Pclass                            Name title  \
# 0              1         0       3         Braund, Mr. Owen Harris    Mr
# 4              5         0       3        Allen, Mr. William Henry    Mr
# 5              6         0       3                Moran, Mr. James    Mr
# 6              7         0       1         McCarthy, Mr. Timothy J    Mr
# 12            13         0       3  Saundercock, Mr. William Henry    Mr
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann    Mr
# 883          884         0       2   Banfield, Mr. Frederick James    Mr
# 884          885         0       3          Sutehall, Mr. Henry Jr    Mr
# 889          890         1       1           Behr, Mr. Karl Howell    Mr
# 890          891         0       3             Dooley, Mr. Patrick    Mr
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
mean = mr_df.Age.mean()

# %%
mean
# Out:
# np.float64(32.368090452261306)

# %%
mr_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# title            0
# Sex              0
# Age            119
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
mr_index = mr_df[mr_df.Age.isnull()].index

# %%
mr_index
# Out:
# Index([  5,  17,  26,  29,  36,  42,  45,  46,  48,  55,
#        ...
#        825, 826, 828, 832, 837, 839, 846, 859, 868, 878],
#       dtype='int64', length=119)

# %%
df.loc[mr_index,'Age'] = mean

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   title     Sex  \
# 0                            Braund, Mr. Owen Harris      Mr    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...     Mrs  female
# 2                             Heikkinen, Miss. Laina    Miss  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)     Mrs  female
# 4                           Allen, Mr. William Henry      Mr    male
# 5                                   Moran, Mr. James      Mr    male
# 6                            McCarthy, Mr. Timothy J      Mr    male
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# title           0
# Sex             0
# Age            58
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        2
# dtype: int64

# %%
miss_df = df[df.loc[:,"title"]=="Miss"]

# %%
miss_df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 2              3         1       3                    Heikkinen, Miss. Laina
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 11            12         1       1                  Bonnell, Miss. Elizabeth
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                       ...
# 866          867         1       2              Duran y More, Miss. Asuncion
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
mean_miss=miss_df.Age.mean()

# %%
mean_miss
# Out:
# np.float64(21.773972602739725)

# %%
miss_df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# title           0
# Sex             0
# Age            36
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        1
# dtype: int64

# %%
miss_index= miss_df[miss_df.Age.isnull()].index

# %%
miss_index
# Out:
# Index([ 28,  32,  47,  82, 109, 128, 180, 198, 229, 235, 240, 241, 264, 274,
#        300, 303, 306, 330, 358, 359, 368, 409, 485, 502, 564, 573, 593, 596,
#        612, 653, 680, 697, 727, 792, 863, 888],
#       dtype='int64')

# %%
df.loc[miss_index,"Age"]=mean_miss

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name title     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    Mr    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs  female  38.0
# 2                             Heikkinen, Miss. Laina  Miss  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Mrs  female  35.0
# 4                           Allen, Mr. William Henry    Mr    male  35.0
#
#    SibSp  Parch            Ticket     Fare Embarked
# 0      1      0         A/5 21171   7.2500        S
# 1      1      0          PC 17599  71.2833        C
# 2      0      0  STON/O2. 3101282   7.9250        S
# 3      1      0            113803  53.1000        S
# 4      0      0            373450   8.0500        S

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# title           0
# Sex             0
# Age            22
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        2
# dtype: int64

# %%
df.title.value_counts()
# Out:
# title
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Major             2
# Mlle              2
# Col               2
# Don               1
# Mme               1
# Ms                1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64
