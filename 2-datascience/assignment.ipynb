# %%
import pandas as pd

# %%
df=pd.read_csv("neet_data1.csv")

# %%
df.head()
# Out:
#             created_at  retweet_count               source  \
# 0  2020-10-31 14:10:28            141  Twitter for Android
# 1  2020-10-31 14:10:11              1   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      Twitter Web App
# 3  2020-10-31 14:09:41            141  Twitter for Android
# 4  2020-10-31 14:09:22              0  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937915394          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816883201       The Rus
# 4  1227501071490113537  Sakshi Yadav
#
#                                     user_description  user_follower_count  \
# 0                                                NaN                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                                NaN                  147
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  str
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  str
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  str
#  5   user_description     36510 non-null  str
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  str
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   str
#  11  tweet                47381 non-null  str
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), str(7)
# memory usage: 4.4 MB

# %%
df.shape
# Out:
# (47381, 13)

# %%
df.describe()
# Out:
#        retweet_count       user_id  user_follower_count  user_friends_count  \
# count   47381.000000  4.738100e+04         4.738100e+04        47381.000000
# mean      331.769190  7.851397e+17         2.465465e+04          681.960322
# std      5146.699757  5.664197e+17         4.153120e+05         2897.910542
# min         0.000000  1.516830e+05         0.000000e+00            0.000000
# 25%         0.000000  2.906389e+09         1.900000e+01           41.000000
# 50%         6.000000  1.071028e+18         1.200000e+02          218.000000
# 75%       150.000000  1.283824e+18         5.960000e+02          705.000000
# max    614304.000000  1.325416e+18         1.393436e+07       490801.000000
#
#        length_of_tweet
# count     47381.000000
# mean        120.293050
# std          35.647986
# min           4.000000
# 25%         114.000000
# 50%         140.000000
# 75%         140.000000
# max         158.000000

# %%
# df.sort_values(by="retweet_count", ascending=False)

# %%
result = df.sort_values(by="retweet_count", ascending=False)[
    ["source", "retweet_count", "user_name", "tweet", "created_at", "user_url"]
].head(1)

result
# Out:
#                    source  retweet_count  \
# 32860  Twitter for iPhone         614304
#
#                                   user_name  \
# 32860  \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
#
#                                                    tweet           created_at  \
# 32860  RT @JoeBiden: America, I\xe2\x80\x99m honored ...  2020-11-08 05:30:01
#
#                       user_url
# 32860  https://t.co/cHZdP4uOdu

# %%
df["retweet_count"].head(10).sum()
# Out:
# np.int64(866)

# %%
df.loc[df["source"] == "Twitter for Android", "retweet_count"].sum()
# Out:
# np.int64(9386742)

# %%
result = df.sort_values(by="user_follower_count", ascending=False)[
    ["user_name", "user_location"]
].head(1)

result
# Out:
#       user_name user_location
# 44367      NDTV         India

# %%
# df["followers_friend_ratio"] = df["user_follower_count"] / df["user_friends_count"] 

# df.head()

# %%
ff=df["user_follower_count"] / df["user_friends_count"]

# %%
df.insert(6, column="followers_friend_ratio", value=ff)
df.head()
# Out:
#             created_at  retweet_count               source  \
# 0  2020-10-31 14:10:28            141  Twitter for Android
# 1  2020-10-31 14:10:11              1   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      Twitter Web App
# 3  2020-10-31 14:09:41            141  Twitter for Android
# 4  2020-10-31 14:09:22              0  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937915394          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816883201       The Rus
# 4  1227501071490113537  Sakshi Yadav
#
#                                     user_description  followers_friend_ratio  \
# 0                                                NaN                0.077778
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                0.770819
# 2  Wisdom is knowing the right path to take, Inte...                0.281343
# ...

# %%
df.isnull().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# followers_friend_ratio      147
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# dtype: int64

# %%
df["user_description"] = df["user_description"].fillna("Twitter user")

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.isnull().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description              0
# followers_friend_ratio      147
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# dtype: int64

# %%
df.dropna(axis=1, inplace=True)

# %%
df
# Out:
#                 created_at  retweet_count              user_id  \
# 0      2020-10-31 14:10:28            141  1250294694937915394
# 1      2020-10-31 14:10:11              1             57059492
# 2      2020-10-31 14:09:48            141           1016022678
# 3      2020-10-31 14:09:41            141  1085818329816883201
# 4      2020-10-31 14:09:22              0  1227501071490113537
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  1168840190426632192
# 47377  2020-10-30 15:29:35           1700           1696615807
# 47378  2020-10-30 15:28:59            167  1313330869113745413
# 47379  2020-10-30 15:28:37            270  1161551282995388416
# 47380  2020-10-30 15:28:14              0  1211810532006612992
#
#                                         user_description  user_follower_count  \
# 0                                           Twitter user                   14
# ...

# %%
df.insert(2,"is_allow",True)

# %%
df
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 0      2020-10-31 14:10:28            141      True  1250294694937915394
# 1      2020-10-31 14:10:11              1      True             57059492
# 2      2020-10-31 14:09:48            141      True           1016022678
# 3      2020-10-31 14:09:41            141      True  1085818329816883201
# 4      2020-10-31 14:09:22              0      True  1227501071490113537
# ...                    ...            ...       ...                  ...
# 47376  2020-10-30 15:29:35              0      True  1168840190426632192
# 47377  2020-10-30 15:29:35           1700      True           1696615807
# 47378  2020-10-30 15:28:59            167      True  1313330869113745413
# 47379  2020-10-30 15:28:37            270      True  1161551282995388416
# 47380  2020-10-30 15:28:14              0      True  1211810532006612992
#
#                                         user_description  user_follower_count  \
# ...

# %%
print("final_df")
final_df = df.drop("tweet", axis=1)
final_df
# Out:
# final_df
#                 created_at  retweet_count  is_allow              user_id  \
# 0      2020-10-31 14:10:28            141      True  1250294694937915394
# 1      2020-10-31 14:10:11              1      True             57059492
# 2      2020-10-31 14:09:48            141      True           1016022678
# 3      2020-10-31 14:09:41            141      True  1085818329816883201
# 4      2020-10-31 14:09:22              0      True  1227501071490113537
# ...                    ...            ...       ...                  ...
# 47376  2020-10-30 15:29:35              0      True  1168840190426632192
# 47377  2020-10-30 15:29:35           1700      True           1696615807
# 47378  2020-10-30 15:28:59            167      True  1313330869113745413
# 47379  2020-10-30 15:28:37            270      True  1161551282995388416
# 47380  2020-10-30 15:28:14              0      True  1211810532006612992
#
#                                         user_description  user_follower_count  \
# ...

# %%
df["created_at"] = df["created_at"].astype(str)
df["year"] = df["created_at"].str.split("-").str[0]
df["month"] = df["created_at"].str.split("-").str[1]
df[["created_at", "month", "year"]]
# Out:
#                 created_at month  year
# 0      2020-10-31 14:10:28    10  2020
# 1      2020-10-31 14:10:11    10  2020
# 2      2020-10-31 14:09:48    10  2020
# 3      2020-10-31 14:09:41    10  2020
# 4      2020-10-31 14:09:22    10  2020
# ...                    ...   ...   ...
# 47376  2020-10-30 15:29:35    10  2020
# 47377  2020-10-30 15:29:35    10  2020
# 47378  2020-10-30 15:28:59    10  2020
# 47379  2020-10-30 15:28:37    10  2020
# 47380  2020-10-30 15:28:14    10  2020
#
# [47381 rows x 3 columns]
