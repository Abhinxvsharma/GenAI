# %%
import pandas as pd

# %%
df = pd.read_csv("Smartphone_Usage_Productivity_Dataset_50000.csv")

# %%
df.head()
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# ...

# %%
df.shape
# Out:
# (50000, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    50000 non-null  str
#  1   Age                        50000 non-null  int64
#  2   Gender                     50000 non-null  str
#  3   Occupation                 50000 non-null  str
#  4   Device_Type                50000 non-null  str
#  5   Daily_Phone_Hours          50000 non-null  float64
#  6   Social_Media_Hours         50000 non-null  float64
#  7   Work_Productivity_Score    50000 non-null  int64
#  8   Sleep_Hours                50000 non-null  float64
#  9   Stress_Level               50000 non-null  int64
#  10  App_Usage_Count            50000 non-null  int64
#  11  Caffeine_Intake_Cups       50000 non-null  int64
#  12  Weekend_Screen_Time_Hours  50000 non-null  float64
# dtypes: float64(4), int64(5), str(4)
# ...

# %%
df.describe()
# Out:
#                 Age  Daily_Phone_Hours  Social_Media_Hours  \
# count  50000.000000       50000.000000        50000.000000
# mean      39.034960           6.509116            4.267250
# std       12.414877           3.170903            2.164743
# min       18.000000           1.000000            0.500000
# 25%       28.000000           3.800000            2.400000
# 50%       39.000000           6.500000            4.300000
# 75%       50.000000           9.200000            6.100000
# max       60.000000          12.000000            8.000000
#
#        Work_Productivity_Score   Sleep_Hours  Stress_Level  App_Usage_Count  \
# count             50000.000000  50000.000000  50000.000000      50000.00000
# mean                  5.503760      6.497744      5.504500         32.43898
# std                   2.874806      1.449551      2.871095         16.12151
# min                   1.000000      4.000000      1.000000          5.00000
# ...

# %%
df.Age.value_counts()
# Out:
# Age
# 54    1235
# 26    1221
# 43    1221
# 60    1214
# 45    1204
# 42    1204
# 38    1203
# 23    1193
# 56    1192
# 27    1185
# 33    1182
# 48    1182
# 44    1180
# 18    1180
# 46    1176
# 39    1170
# 24    1169
# 53    1169
# 41    1169
# 49    1168
# 55    1167
# 47    1165
# 19    1161
# 31    1161
# 20    1160
# 58    1159
# 29    1155
# 59    1151
# 37    1150
# 28    1149
# 52    1146
# 35    1143
# 34    1139
# 25    1138
# 36    1134
# 22    1133
# 32    1132
# 21    1122
# 50    1117
# 30    1113
# 57    1104
# 51    1104
# 40    1080
# Name: count, dtype: int64

# %%
df.drop("Daily_Phone_Hours", axis=1, inplace=True)

# %%
df
# Out:
#       User_ID  Age  Gender      Occupation Device_Type  Social_Media_Hours  \
# 0          U1   58    Male    Professional     Android                 6.7
# 1          U2   25    Male    Professional     Android                 1.5
# 2          U3   19    Male         Student         iOS                 5.7
# 3          U4   35  Female  Business Owner         iOS                 2.5
# 4          U5   33    Male      Freelancer     Android                 1.3
# ...       ...  ...     ...             ...         ...                 ...
# 49995  U49996   44    Male  Business Owner     Android                 5.4
# 49996  U49997   42   Other  Business Owner     Android                 7.4
# 49997  U49998   27  Female      Freelancer         iOS                 2.5
# 49998  U49999   41  Female  Business Owner         iOS                 3.0
# 49999  U50000   46   Other      Freelancer     Android                 2.8
#
# ...

# %%
df.Age.describe()
# Out:
# count    50000.000000
# mean        39.034960
# std         12.414877
# min         18.000000
# 25%         28.000000
# 50%         39.000000
# 75%         50.000000
# max         60.000000
# Name: Age, dtype: float64

# %%
df.filter(items=["Age"])
# Out:
#        Age
# 0       58
# 1       25
# 2       19
# 3       35
# 4       33
# ...    ...
# 49995   44
# 49996   42
# 49997   27
# 49998   41
# 49999   46
#
# [50000 rows x 1 columns]

# %%
df.loc[(df.loc[:,"Occupation"] == "Student") & (df.loc[:,"Work_Productivity_Score"] > 7) & (df.loc[:,"Gender"]=="Male")]
# Out:
#       User_ID  Age Gender Occupation Device_Type  Social_Media_Hours  \
# 6          U7   26   Male    Student         iOS                 6.1
# 159      U160   58   Male    Student         iOS                 4.5
# 180      U181   23   Male    Student     Android                 6.5
# 183      U184   22   Male    Student         iOS                 5.6
# 268      U269   22   Male    Student         iOS                 3.4
# ...       ...  ...    ...        ...         ...                 ...
# 49900  U49901   31   Male    Student     Android                 7.2
# 49932  U49933   33   Male    Student         iOS                 6.4
# 49942  U49943   53   Male    Student     Android                 0.7
# 49951  U49952   38   Male    Student     Android                 7.9
# 49985  U49986   29   Male    Student         iOS                 4.1
#
#        Work_Productivity_Score  Sleep_Hours  Stress_Level  App_Usage_Count  \
# ...
